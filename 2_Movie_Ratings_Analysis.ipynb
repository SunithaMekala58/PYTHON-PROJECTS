# %% [markdown]
# ## Movie Rating Analysis (By Sunitha Mekala)

# %%
# MOVIE RATING ANALYSIS (ADVANCED VISUALISATION)
import pandas as pd
import os

# %%
os.getcwd() #if you want to change the working directory
# Out:
# 'C:\\Users\\SUNITHA'

# %%
#Reading the excel file
movies = pd.read_csv(r'D:\SUNITHA\Sample Datasets\Movie-Rating.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
# type of movies dataset
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
# length of movies dataset
len(movies)
# Out:
# 559

# %%
# Displays top 5 records of the dataset
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
# Displays bottom 5 records
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
# Displays shape of the dataset as (rows, cols)
movies.shape
# Out:
# (559, 6)

# %%
# Check if there are any missing values
movies.isnull().sum()
# Out:
# Film                         0
# Genre                        0
# Rotten Tomatoes Ratings %    0
# Audience Ratings %           0
# Budget (million $)           0
# Year of release              0
# dtype: int64

# %%
# Check the info related to dataset as shows col name, datatype etc.
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
# Displays the col names
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %% [markdown]
# ### Here we need to change the column names for better understanding

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions','Year']

# %%
movies.head(1) # Checking if col names have been updated
# Out:
#                     Film   Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer   Comedy            87              81
#
#    BudgetMillions  Year
# 0               8  2009

# %% [markdown]
# ### If we look at the year, the data type is int, but when you look at the mean value it is showing 2009 which is meaningless.
# ### We have to change to categroy type,
# ### also from object datatype we will convert to category datatypes

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.Genre = movies.Genre.astype('category')

# %%
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.Year # is it real no. year you can take average,min,max but out come have no meaning
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
movies.describe() 
#now when you see the describt you will get only integer value mean, standard deviation which is meaning full
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
#How to work with joint plots

from matplotlib import pyplot as plt # visualisation
import seaborn as sns #advanced visualisation

# %matplotlib inline  
#All the plot shuld be inside the line
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * basically joint plot is a scatter plot & it will find the relation b/w audiene & critics
# * also if you look up you can find the uniform distribution (critics)and normal distriution (audience)

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating')

# %% [markdown]
# ### Audience rating is more dominant then critics rating
# ### Based on this we find out as most people are most likelihood to watch audience rating & less likely to watch critics rating
# ### let me explain the excel - if you filter audience rating & critic rating. critic rating has very low values compare to audience rating

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating', kind = 'hex')

# %%
#Histograms

m1 = sns.distplot(movies.AudienceRating)

#y - axis generated by seaborn automatically that is the advantage of seaborn gallery

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating', kind = 'reg')

# %% [markdown]
# # Outlier Detection

# %%
# Get the first quantile
Q1 = movies['AudienceRating'].quantile(0.25)
# Get the third quantile
Q3 = movies['AudienceRating'].quantile(0.75)

# IQR - Inter Quantile Range
IQR = Q3 - Q1

#define bounds
lower = Q1-1.5*IQR
upper = Q3+1.5*IQR

outlier = movies[(movies["AudienceRating"]<lower) | 
                 (movies["AudienceRating"]>upper)]
print("Outliers:\n", outlier)
# Out:
# Outliers:
#                        Film    Genre  CriticRating  AudienceRating  \
# 293  Paranormal Activity 2   Horror             0               0
# 354     Something Borrowed  Romance             0               0
#
#      BudgetMillions  Year
# 293               3  2010
# 354              35  2011

# %% [markdown]
# ## Clear Explanation of Outlier Detection

# %%
# Get the first quantile
Q1 = movies['AudienceRating'].quantile(0.25)
Q1
# Out:
# 47.0

# %%
# Get the third quantile
Q3 = movies['AudienceRating'].quantile(0.75)
Q3
# Out:
# 72.0

# %%
# IQR - Inter Quantile Range
IQR = Q3 - Q1
IQR
# Out:
# 25.0

# %%
#define bounds
lower = Q1-1.5*IQR
lower
# Out:
# 9.5

# %%
upper = Q3+1.5*IQR
upper
# Out:
# 109.5

# %%
outlier = movies[(movies["AudienceRating"]<lower) | 
                 (movies["AudienceRating"]>upper)]

# %%
outlier
# Out:
#                       Film    Genre  CriticRating  AudienceRating  \
# 293  Paranormal Activity 2   Horror             0               0
# 354     Something Borrowed  Romance             0               0
#
#      BudgetMillions  Year
# 293               3  2010
# 354              35  2011

# %%
# Histograms
m1 = sns.distplot(movies.AudienceRating)

# %%
sns.set_style('darkgrid')
m2 = sns.distplot(movies.AudienceRating, bins = 10)

# %%
n1 = plt.hist(movies.AudienceRating, bins = 15)

# %% [markdown]
# ### Normal distribution & called as bell curve

# %%
sns.set_style('white')
n1 = plt.hist(movies.AudienceRating, bins = 20)

# %% [markdown]
# ### Here CriticRating is Uniform distribution

# %%
n1 = plt.hist(movies.CriticRating, bins=20)

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
plt.hist(movies.BudgetMillions) 
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
# Below plots are stacked histogram becuase overlaped

plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins = 20)
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins = 20)
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins = 20)
plt.legend(['Action', 'Thriller', 'Drama'], loc = 'upper right')
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,\
          movies[movies.Genre == 'Drama'].BudgetMillions, \
          movies[movies.Genre == 'Thriller'].BudgetMillions, \
          movies[movies.Genre == 'Comedy'].BudgetMillions],
         bins = 20, stacked = True)
plt.show()

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %% [markdown]
# ## Note: if you have 100 categories you cannot copy & paste all the things

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating', fit_reg=False)

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
sns.lmplot(data=movies, x='CriticRating', y='AudienceRating',\
                 fit_reg=False, hue = 'Genre')

# %% [markdown]
# ## Kernal Density Estimate plot ( KDE PLOT)
# ## how can i visulize audience rating & critics rating using scatterplot

# %%
k1 = sns.kdeplot(data = movies, x = 'CriticRating', y = 'AudienceRating')

# where do u find more density and how density is distibuted across - from the the visualissation
# center point is kernal, this is called KDE & instead of dots it visualize like this
# we can able to clearly see the spread at the audience ratings

# %%
k1 = sns.kdeplot(data = movies, x = 'CriticRating', y = 'AudienceRating', 
                 shade_lowest = False, cmap='Reds')

# %%
k1 = sns.kdeplot(data = movies, x = 'CriticRating', y = 'AudienceRating',
                 shade = True, shade_lowest=False, cmap='Greens')

# %%
sns.set_style('dark')
k1 = sns.kdeplot(data = movies, x = 'BudgetMillions', y = 'AudienceRating',
                 shade_lowest=False, cmap='Greens_r')

# %% [markdown]
# # Subplots

# %%
f, ax = plt.subplots(1,2, figsize = (12,6))

# %%
f , axes = plt.subplots(1,2, figsize = (12,6))
k1 = sns.kdeplot(x = movies.BudgetMillions, y = movies.AudienceRating, ax = axes[0])
k1 = sns.kdeplot(x = movies.BudgetMillions, y = movies.CriticRating, ax = axes[1])

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>,
#        <Axes: xlabel='BudgetMillions', ylabel='CriticRating'>],
#       dtype=object)

# %% [markdown]
# # BoxPlots

# %%
w = sns.boxplot(data = movies, x = 'Genre', y = 'CriticRating', palette = 'Set2')

# %% [markdown]
# # Violin Plot

# %%
z = sns.violinplot(data = movies, x = 'Genre', y = 'CriticRating', palette = 'Set2')

# %%
w1 = sns.boxplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'CriticRating',
                palette = 'Set1')

# %%
z = sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'CriticRating',
                palette = 'Set1')

# %% [markdown]
# # Creating a Facet Grid

# %%
g = sns.FacetGrid (data = movies, row = 'Genre', col = 'Year', hue = 'Genre') #kind of subplots

# %%
plt.scatter(movies.CriticRating, movies.AudienceRating)
plt.show()

# %% [markdown]
# ## Scatter Plots are mapped in FacetGrid

# %%
g = sns.FacetGrid (data = movies, row = 'Genre', col = 'Year', hue = 'Genre') #kind of subplots
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating' ) #scatterplots are mapped in facetgrid

# %%
# you can populate any type of chart. 

g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillions') #scatterplots are mapped in facetgrid

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=50, linewidth=0.5,edgecolor='purple')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating',**kws ) #scatterplots are mapped in facetgrid

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (10,10))

k1 = sns.kdeplot(x = movies.BudgetMillions,y = movies.AudienceRating,ax=axes[0,0])
k2 = sns.kdeplot(x = movies.BudgetMillions,y = movies.CriticRating,ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year',
                   y = 'CriticRating', palette = 'Set1', ax=axes[1,0])

k4 = sns.kdeplot(x = movies.CriticRating,y = movies.AudienceRating,
                 shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(x = movies.CriticRating, y = movies.AudienceRating,
                  cmap='Reds',ax = axes[1,1])

plt.show()

# %% [markdown]
# ## How can you style your dashboard  using different color map

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(x= movies.BudgetMillions,y = movies.AudienceRating, \
                 shade = True, shade_lowest=True,cmap = 'BuPu', \
                 ax = axes[0,0])
k1b = sns.kdeplot(x = movies.BudgetMillions,y = movies.AudienceRating, \
                 cmap = 'viridis',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(x = movies.BudgetMillions,y = movies.CriticRating,\
                 shade=True, shade_lowest=True, cmap='cividis',\
                 ax = axes[0,1])
k2b = sns.kdeplot(x = movies.BudgetMillions,y = movies.CriticRating,\
                  cmap = 'magma', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'], \
                   x='Year', y = 'CriticRating', ax=axes[1,0], palette = 'Set1')

#plot[1,1]
k4 = sns.kdeplot(x = movies.CriticRating,y = movies.AudienceRating, \
                 shade = True,shade_lowest=False,cmap='PuBuGn', \
                 ax=axes[1,1])

k4b = sns.kdeplot(x = movies.CriticRating, y = movies.AudienceRating, \
                  cmap='YlOrBr',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()
